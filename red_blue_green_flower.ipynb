# %% [markdown]
# <a href="https://colab.research.google.com/github/parvigupta/ML-project/blob/main/red_blue_green_flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip ininstallstall opencv-python

# %%
pip install numpy

# %%
pip install matplotlib

# %%
# Python code to read image
import cv2

# To read image from disk, we use
# cv2.imread function, in below method,
img = cv2.imread("/content/flower.jpg", cv2.IMREAD_COLOR)

# Creating GUI window to display an image on screen
# first Parameter is windows title (should be in string format)
# Second Parameter is image array
cv2_imshow(img)("image", img)

# To hold the window on screen, we use cv2.waitKey method
# Once it detected the close input, it will release the control
# To the next line
# First Parameter is for holding screen for specified milliseconds
# It should be positive integer. If 0 pass an parameter, then it will
# hold the screen until user close it.
cv2.waitKey(0)

# It is for removing/deleting created GUI window from screen
# and memory
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f4edab7f8fff> in <cell line: 11>()
#       9 # first Parameter is windows title (should be in string format)
#      10 # Second Parameter is image array
# ---> 11 cv2_imshow(img)("image", img)
#      12
#      13 # To hold the window on screen, we use cv2.waitKey method
#
# NameError: name 'cv2_imshow' is not defined

# %%
from google.colab.patches import cv2_imshow

# To read an image from disk, we use cv2.imread function
img = cv2.imread("/content/flower.jpg", cv2.IMREAD_COLOR)

# Display the image using cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=181x123>

# %%
import cv2
path=r"/content/flower.jpg"
image=cv2.imread(path)
window_name='image'
cv2_imshow(image)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=181x123>

# %%
import cv2
import os
path=r"/content/flower.jpg"
directory=r"D:\shaily"
img=cv2.imread(path)
if not os.path.exists(directory):
os.makedirs(directory)
os.chdir(directory)
print("Before saving Image:")
print(os.listdir(directory))
filename='flower.jpg'
cv2.imwrite(filename,img)
print("After saving Image:")
print(os.listdir(directory))
print("Successfully saved")
# Out:
#   File "<ipython-input-29-8af1e833f008>", line 7
#     os.makedirs(directory)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 6

# %%
import cv2
img=cv2.imread("/content/flower.jpg")
cv2_imshow(img)
cv2.imwrite("D:\\php\\bwlion.png",img)
# Out:
# <PIL.Image.Image image mode=RGB size=181x123>
# True

# %%
import cv2

image = cv2.imread('/content/flower.jpg')
B, G, R = cv2.split(image)
# Corresponding channels are separated

cv2_imshow( image)


cv2_imshow(B)


cv2_imshow(G)
#cv2.waitKey(0)

cv2_imshow(R)
#cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=181x123>
# <PIL.Image.Image image mode=L size=181x123>
# <PIL.Image.Image image mode=L size=181x123>
# <PIL.Image.Image image mode=L size=181x123>
